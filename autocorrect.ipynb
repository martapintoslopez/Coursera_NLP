# %%
import pandas as pd
import re
from collections import Counter 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data/DatasetFinal.csv", index_col=0)
df.head(2)
# Out:
#              Course Title  Rating           Level           Schedule  \
# 0       Fashion as Design     4.8  Beginner level  Flexible schedule
# 1  Modern American Poetry     4.4  Beginner level  Flexible schedule
#
#   What you will learn                             Skill gain  \
# 0       Not specified  Art History, Art, History, Creativity
# 1       Not specified                          Not specified
#
#                                              Modules  \
# 0  Introduction, Heroes, Silhouettes, Coutures, L...
# 1  Orientation, Module 1, Module 2, Module 3, Mod...
#
#                                           Instructor  \
# 0  Anna Burckhardt, Paola Antonelli, Michelle Mil...
# 1                                        Cary Nelson
#
#                                    Offered By              Keyword  \
# 0                    The Museum of Modern Art  Arts and Humanities
# 1  University of Illinois at Urbana-Champaign  Arts and Humanities
#
#                                           Course Url  \
# 0      https://www.coursera.org/learn/fashion-design
# 1  https://www.coursera.org/learn/modern-american...
#
#    Duration to complete (Approx.)  Number of Review
# 0                            20.0              2813
# 1                            34.0               100

# %%
df.shape
# Out:
# (8342, 13)

# %%
def process_data(titles):
    """
    Input: 
        Colum of cour 
    Output: 
        words: a list containing all the words in the corpus (text file you read) in lower case. 
    """
    words = [] # return this variable correctly
    #title = []
    
    #Create a list with all the titles
    title = [i for i in titles]
    print("Number of titles: ",len(title))

    #Convert all the titles to a string
    text = ""
    for texts in title:
        text = text + ' ' + texts
    print("Number of characters: ", len(text))    
    
    # convert all letters to lower case
    text_lowercase = text.lower()

    # some regex to tokenize the string to words and return them in a list
    words = re.findall(r'\w+', text_lowercase)
    print('Number of words: ',len(words))
    
    return words

# %%
words = process_data(df["Course Title"])
# Out:
# Number of titles:  8342
# Number of characters:  362835
# Number of words:  46836

# %% [markdown]
# # Create Dictionary with Frequencies
# - The dictionary's keys are words.
# - The value for each word is the number of times that word appears in the corpus.

# %%
# create vocab
vocab = set(words)
print(vocab)
print('Number of different words: ',len(vocab))
# Out:
# {'firebase', 'shortest', 'esprit', 'points', 'liquid', 'न', 'comfort', 'producción', 'campaigns', 'antibióticos', 'lathe', 'التوتر', 'shi', 'innate', 'すべての人のためのaiリテラシー講座', 'enfoque', 'actúa', 'accountancy', 'channel', 'socially', 'qualitative', 'politics', 'propios', 'basadas', 'attacks', 'criminal', 'interests', 'informatics', 'técnica', 'plants', 'develop', 'defined', 'conoce', 'coach', 'théorie', 'guiding', 'eszközök', 'research', 'réforme', 't', 'peace', 'liquids', 'estate', 'satellite', 'hasta', 'displacement', 'المواهب', 'fondements', 'geopolitics', 'transistores', 'personnels', 'with', 'العرض', 'warring', 'opérationnelle', 'général', 'uncertainty', 'nested', 'dev', 'audience', 'opera', 'recruitment', 'metaphysics', 'econometrics', 'gobierno', '360', 'portfolio', 'megbirkózni', 'evidence', 'rotational', 'migrate', 'desarrollando', 'textual', 'realidad', 'emotions', 'urbains', 'entrepreneurial', 'medication', 'aop', 'procesamiento', 'integration', 'family', 'classification', 'built', 'supports', 'tribunals', 'fuera', 'concept', 'ip', 'backend', 'jumpstart', 'validate', 'action', 'pdf', 'exit', 'analysis', 'preparing', 'amor', 'apache', 'résultats', 'diversifying', 'enhancing', 'operational', 'toolkit', 'defender', 'caracterización', 'investigating', 'interventions', 'election', 'steps', 'origens', 'quels', 'certificaciones', 'desarrollar', 'others', 'hidden', 'inversión', 'cities', 'oficio', 'express', '000', 'dba', 'force', 'box', 'exercer', 'jurídica', 'parents', 'organisations', 'dopage', '创新', 'live', 'fighting', 'prudence', 'em', 'lower', 'unix', 'fitness', 'bible', 'tango', 'foundations', 'ear', 'selfhood', 'kidney', 'cliente', 'ممارسات', 'per', 'parler', 'ellos', 'non', 'usos', 'instructional', 'mistakes', '40', 'composition', 'equine', 'professionals', 'volunteer', 'consequences', '护理研究', 'time', 'funcionamento', 'editing', 'dense', 'phet', 'agir', 'overcoming', 'upright', 'astronomical', '基礎光學一', 'old', 'selling', 'networking', 'trello', 'postharvest', 'matemática', 'recursos', 'canada', 'release', 'photo', 'neuropático', 'rpa', 'flow', 'dinosaurs', 'clean', 'mindful', 'inbound', 'age', 'corto', 'الأعمال', 'octets', 'र', 'rmf', 'tiktok', '紅樓夢', 'designs', 'والتقديم', 'autonomous', 'vendas', 'recovery', 'b1', 'المتعاملين', 'applied', 'diálogo', 'engineering', 'enfant', 'visualizing', 'abstraction', 'semicrítico', 'evaluating', 'dénommer', 'desarrolla', 'carbono', 'small', 'subjectivity', 'launch', 'crear', 'città', 'personalised', 'technique', 'adolescents', 'fechando', 'ictus', 'cell', 'impacts', '매니퓰레이션', '700', 'ganar', 'sequencing', 'cognitive', 'physics', 'products', 'nca', 'yoga', 'annual', 'college', 'goal', 'integral', 'sizing', 'cambios', 'empresas', '단기집중과정', 'سيرة', 'rh', 'classics', 'creation', '19', 'pepsico', 'leaders', 'mutations', 'defining', 'conditional', 'à', 'introducing', 'incentive', 'publish', '로봇', '哲學觀與方法論', 'وأنظمة', 'world', 'filtrage', 'realities', 'beginners', 'invitation', 'write', 'variation', 'moving', 'relações', 'changement', 'tricks', 'methodologies', 'scikit', 'percepción', 'populations', 'red', 'path', '5g', 'computer', 'atención', 'vyombo', 'uncommon', 'maîtriser', 'east', '10', '經濟學概論', 'shareholders', 'académica', 'chords', 'ذهنية', 'resistance', 'ا', 'slide', 'démocraties', 'قوية', 'abordaje', 'audiences', 'arctic', 'gestion', '新教伦理与资本主义精神', 'seizures', 'rehearsing', 'rest', 'cybersecurity', 'كيفية', 'interactions', 'macro', 'axis', 'generales', 'board', 'scientifique', 'ancient', 'databricks', 'bebidas', 'connectivity', 'tgnc', 'proactive', 'testes', 'law', 'applications', 'ciudades', 'flavor', 'half', 'exitosa', 'alto', 'instituciones', 'tecnología', 'oculto', 'dans', 'strategy', 'candidate', 'reducing', 'al', 'educativa', 'footprint', 'utility', 'crash', 'final', 'delivering', 'mobility', 'managerial', 'scalable', 'dal', '又見大觀', 'cov', 'clock', 'renouvelable', 'avc', 'negociações', 'professionalism', 'pi', 'sick', '学习', 'vários', 'infection', 'latinoamérica', 'palo', 're ...
# Number of different words:  6275

# %%
# create vocab including word count
counts = {}
counts = Counter(words)
print('Number of different words: ',len(counts)) 
print(f"The count for the word 'specialization' is {counts.get("specialization")}")
# Out:
# The word 'specialization' in 1360
# Number of different words:  6275

# %% [markdown]
# # Dictionary of Probabilities
# - Compute the probability that each word will appear
#
# $$P(w_i) = \frac{C(w_i)}{M} \tag{Eqn-2}$$
#
# where
#
# $C(w_i)$ is the total number of times $w_i$ appears in the corpus.
#
# $M$ is the total number of words in the corpus.

# %%
def get_probs(word_count_dict):
    '''
    Input:
        word_count_dict: The wordcount dictionary where key is the word and value is its frequency.
    Output:
        probs: A dictionary where keys are the words and the values are the probability that a word will occur. 
    '''
    probs = {}  # return this variable correctly

    # get the total count of words for all words in the dictionary
    m = sum(word_count_dict.values())
    probs = {word: count/m for word, count in word_count_dict.items()}

    return probs

# %%
probs = get_probs(counts)
print(f"The probability for the word 'specialization' is {probs.get("specialization")}")
print(f"The probability for the word 'fashion' is {probs.get("fashion")}")
# Out:
# The probability for the word 'specialization' is 0.029037492527115894
# The probability for the word 'fashion' is 0.0002989153642497224
